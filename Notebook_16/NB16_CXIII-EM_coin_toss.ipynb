# %% [markdown]
# # Notebook 16: Expectation Maximization in practice

# %% [markdown]
# ## Learning Goal
# The goal of this notebook is to gain intuition for Expectation Maximization using a simple example involving coin tosses.
#
# ## Overview
#
# In Section XIV, we introduce Expectation-Maximization (EM) as a practical way to perform maximum likelihood estimation (MLE) even when some of the data is hidden (i.e in the presence of latent or hidden variables). To better understand EM, in this short notebook we'll explore a very simple coin-tossing example adapted from [Do and Batzoglou, Nat. Biotechnol. (2008)](https://www.nature.com/articles/nbt1406).
#
# Suppose that we are given two coins A and B with unkown bias $\theta_A$ and $\theta_B$, respectively. Our goal is to estimate the bias vector $\boldsymbol{\theta}= (\theta_A, \theta_B)$ from the outcomes of the following experiment:
#
# <blockquote>
# First choose one coin at random. Then toss the selected coin 10 times independently and record the number of heads observed. Repeat this procedure 5 times.
# </blockquote>
#
# Formally, let $z_i\in\{A,B\}$ be the coin selected in experiment $i$ and $x_i\in\{0,1,\cdots 10\}$ be the number heads recorded by tossing $z_i$ 10 times. Since we conduct $n=5$ such experiments, we can summarize the outcomes of these 50 tosses by two vectors: $\boldsymbol{x}=(x_1,x_2\cdots, x_5)$ and $\boldsymbol{z}=(z_1,z_2,\cdots, z_5)$.

# %% [markdown]
# ### Exercise 1: What if we know everything?
#
#  * Consider first the case where we have complete knowledge of the experiment, namely, both $\boldsymbol{x}$ and $\boldsymbol{z}$ are known. How would you intuitively estimate the biases of the two coins  $\boldsymbol{\theta}= (\theta_A, \theta_B)$ ?<br>
#  <b>Intuitively, it would make sense to divide the x value corresponding to a z by 10 (the number of times tossed).</b><br><br>
#
#  * What's the likelihood of observing the complete outcomes of these experiments? In other words, what is $P(\boldsymbol{x},\boldsymbol{z}| n,\boldsymbol{\theta} )$? You may assume this is a Bernoulli trial. Namely, every time coin A(B) is tossed, we have, with probability $\theta_A$($\theta_B$), that the outcome is heads.<br><br>
# <b></b>$\prod_{i}^{n=5}\binom{10}{x_i}\theta_{A}^{x^i}(1-\theta_{A})^{x_i}+\binom{10}{x_i}\theta_{B}^{x^i}(1-\theta_{B})^{x_i}$<br><br>
#
#  * What's the Maximum Likelihood Estimator (MLE)? Is this consistent with your intuition?<br>
#  <b>As expected, MLE is the proportion of heads to number of throws.</b><br><br>

# %% [markdown]
# ## Comparing MLE and EM
#
# To test your answer, let's do some numerics! We will compare the MLE estimates of biases with an Expectation Maximization procedure where we do not know ${\bf z}$. The following code computes our best guess for the biases using MLE -- assuming we know the identity of the coin used -- and compares it estimates arrived at using an EM procedure where we have no knowledge about which coin was being tossed (though we know the same coin was tossed 10 times).

# %%
import numpy as np
from scipy.special import comb
import math


def compute_likelihood(obs, n, pheads): # No surprise, it's Binomial!!!

    likelihood = comb(n, obs, exact=True)*(pheads**obs)*(1.0-pheads)**(n-obs)

    return likelihood

# generate experiments
#num_coin_toss = 10 # each experiment contains num_coin_toss tosses
num_coin_toss = 10
num_exp = 5  # we perform 5 such experiments
theta_A_true = 0.8 
theta_B_true = 0.4
coin_choice = np.zeros(num_exp) # initialize: 0 for A and 1 for B
head_counts = np.zeros(num_exp)

# MLE 
MLE_A = 0.0
MLE_B = 0.0

# generate the outcomes of experiment
for i in np.arange(num_exp):
    
    if np.random.randint(2) == 0: # coin A is selected
        head_counts[i] = np.random.binomial(num_coin_toss , theta_A_true, 1) # toss coin A num_coin_toss times
        MLE_A = MLE_A +  head_counts[i] # add the number of heads observed to total headcounts 
    
    else: # coin B is selected 
        head_counts[i] = np.random.binomial(num_coin_toss , theta_B_true, 1) # toss coin B num_coin_toss times
        coin_choice[i] = 1  # record the selection of coin B during experiment i 
        MLE_B = MLE_B +  head_counts[i] # add the number of heads observed to total headcounts 
    
tail_counts = num_coin_toss - head_counts


# MLE is merely the proportion of heads for each coin toss
MLE_A = MLE_A / ((num_exp - np.count_nonzero(coin_choice))*num_coin_toss)
MLE_B = MLE_B / (np.count_nonzero(coin_choice)*num_coin_toss)



# initialize the pA(heads) and pB(heads), namely, coin biases
pA_heads = np.zeros(100); 
pB_heads = np.zeros(100); 

pA_heads[0] = 0.60 # initial guess
pB_heads[0] = 0.50 # initial guess

# E-M begins!
epsilon = 0.001   # error threshold
j = 0 # iteration counter
improvement = float('inf')

while (improvement > epsilon):
    
    expectation_A = np.zeros((num_exp,2), dtype=float) 
    expectation_B = np.zeros((num_exp,2), dtype=float)
    
    for i in np.arange(min(len(head_counts),len(tail_counts))):
        
        eH = head_counts[i]
        eT = tail_counts[i]
        
        # E step:
        lA = compute_likelihood(eH, num_coin_toss, pA_heads[j])
        lB = compute_likelihood(eH, num_coin_toss, pB_heads[j])
        
        weightA = lA / (lA + lB)
        weightB = lB / (lA + lB)
              
        expectation_A[i] = weightA*np.array([eH, eT])
        expectation_B[i] = weightB*np.array([eH, eT])

  
    # M step
    theta_A = np.sum(expectation_A, axis = 0)[0] / np.sum(expectation_A) 
    theta_B = np.sum(expectation_B, axis = 0)[0] / np.sum(expectation_B) 

    print('At iteration %d, theta_A = %2f,  theta_B = %2f' % (j, theta_A, theta_B))
    
    pA_heads[j+1] = sum(expectation_A)[0] / sum(sum(expectation_A)); 
    pB_heads[j+1] = sum(expectation_B)[0] / sum(sum(expectation_B)); 

    improvement = max( abs(np.array([pA_heads[j+1],pB_heads[j+1]]) - np.array([pA_heads[j],pB_heads[j]]) ))
    j = j+1

# END of E-M, print the outcome

print('E-M converges at iteration %d' %j)
print('RESULT:')
print('E-M: theta_A = %2f,  theta_B = %2f' % (theta_A, theta_B))
print('MLE with complete data: theta_A = %2f,  theta_B = %2f' % (MLE_A, MLE_B))
# Out:
# At iteration 0, theta_A = 0.752380,  theta_B = 0.530268
# At iteration 1, theta_A = 0.859496,  theta_B = 0.469560
# At iteration 2, theta_A = 0.922854,  theta_B = 0.462436
# At iteration 3, theta_A = 0.945700,  theta_B = 0.467672
# At iteration 4, theta_A = 0.949103,  theta_B = 0.468950
# At iteration 5, theta_A = 0.949408,  theta_B = 0.469152
# E-M converges at iteration 6
# RESULT:
# E-M: theta_A = 0.949408,  theta_B = 0.469152
# MLE with complete data: theta_A = 0.833333,  theta_B = 0.400000

# %% [markdown]
# ### Exercise 2
#
#  * How fast does EM converge? Is the converged result close to what you'd get from MLE? <br>
#  <b>After varying the number of coin tosses and running the program multiple times, I found that EM typically converges at between 5 and 21 iterations in the case there are only 10 coin tosses. However, as one might expect, increasing the number of coin tosses shortens the iterations and causes MLE and EM to converge to the same values. When the number of coin tosses is ten, EM and MLE are still close, but can be different up to 10%-15%.</b><br><br>
#  * Following Exercise 1, what's the objective function we're optimizing in the E-step? Does this function have a *unique global maximum*? <br>
# <b>The unique global maximum should be the actual biases of the coin. The function we are optimizing is the variational free energy. </b><br><br>
#
#  * Compare both the results of MLE and EM to the actual bias (i.e. *theta_A_true*  and *theta_B_true* in the snippet above), comment on their performance.<br>
# <b>The original results given in the instructor's iteration for EM is $\theta_A =0.765867 $ and $\theta_B = 0.396945$. For MLE, they are $\theta_A =0.766667 $ and $\theta_B = 0.350000$. Given the actual biases, the results appear to be close to them. However, upon running the program multiple times, EM appeared to perform better.  </b>

# %% [markdown]
# ## Final remarks: a few practical tricks
#
# From Exercise 2 and Section XIV, we know that the E-M algorithm often approximates the MLE even in the presence of latent (hidden variables). Like with most optimization methods for nonconcave functions, E-M only guarantees convergence to a local maximum of the objective function. For this reason, its performance can be boosted by running the EM procedure starting with multiple initial parameters.

# %% [markdown]
# ### Exercise 3
#
# * Now instead of having a fixed initial guess of coin biases (i.e. *pA_heads[0]* and *pB_heads[0]* in the snippet), draw these values uniformly at random from $[0,1]$ and run the E-M algorithm. Repeat this twenty times and report what you observed. What's the best initial guess that gives the closest estimate to the true parameters?<br>
# <b>In the case that the number of coin tosses is 10, there seems to be a very slight correlation between the initial guess and error. For $\theta_B$, the higher the initial guess, the higher the error. For $\theta_A$, the higher the initial guess, the lower the error.  </b><br><br>
#
# * As we discussed in Section X (LinReg), **Maximum a posteriori (MAP)** estimation differs from MLE in that it employs an augmented objective function which incorporates a prior distribution over the quantities we want to estimate, and the prior distribution can be think of as a regularizer for the objective fuction used in MLE. Here we will explore how to extend E-M to MAP estimation.
#
#   (1) First derive the MAP estimate for the one-coin-flipping example, namely,
#   $$
#   \hat{{\theta}}_{MAP}(\boldsymbol{x}) = \arg\max_{\theta\in[0,1]} \log P(\boldsymbol{x}|n,{\theta} ) + \log P({\theta}),
#   $$
#   where
#   $$P(\boldsymbol{x}|n,{\theta}) = \prod_{i=1}^{10} \text{Binomial} (x_i|n,\theta)$$
#
#   $$P({\theta})=\mathcal{N}(\theta|\mu, \sigma)$$
#
#   (2) Based on (1), now modify the E-M snippet above to incorporate this prior distribution into the **M-step**. Comment on the performance. For the prior choice, try $P(\boldsymbol{\theta})=\mathcal{N}(\theta_A|0.83, 1)\mathcal{N}(\theta_B|0.37, 1)$.

# %%
import numpy as np
from scipy.special import comb
import math

errorsA = []
errorsB = []
differencesFromTrueThetaA = []
differencesFromTrueThetaB = []
initialGuessesA = []
initialGuessesB = []

def compute_likelihood(obs, n, pheads): # No surprise, it's Binomial!!!

    likelihood = comb(n, obs, exact=True)*(pheads**obs)*(1.0-pheads)**(n-obs)

    return likelihood
for iteration in range(0,100):
    # generate experiments
    #num_coin_toss = 10 # each experiment contains num_coin_toss tosses
    num_coin_toss = 10
    num_exp = 5  # we perform 5 such experiments
    theta_A_true = 0.8 
    theta_B_true = 0.4
    coin_choice = np.zeros(num_exp) # initialize: 0 for A and 1 for B
    head_counts = np.zeros(num_exp)

    # MLE 
    MLE_A = 0.0
    MLE_B = 0.0

    # generate the outcomes of experiment

    for i in np.arange(num_exp):

        if np.random.randint(2) == 0: # coin A is selected
            head_counts[i] = np.random.binomial(num_coin_toss , theta_A_true, 1) # toss coin A num_coin_toss times
            MLE_A = MLE_A +  head_counts[i] # add the number of heads observed to total headcounts 

        else: # coin B is selected 
            head_counts[i] = np.random.binomial(num_coin_toss , theta_B_true, 1) # toss coin B num_coin_toss times
            coin_choice[i] = 1  # record the selection of coin B during experiment i 
            MLE_B = MLE_B +  head_counts[i] # add the number of heads observed to total headcounts 

    tail_counts = num_coin_toss - head_counts


    # MLE is merely the proportion of heads for each coin toss
    #MLE_A = MLE_A / ((num_exp - np.count_nonzero(coin_choice))*num_coin_toss)
    #MLE_B = MLE_B / (np.count_nonzero(coin_choice)*num_coin_toss)


    # initialize the pA(heads) and pB(heads), namely, coin biases
    pA_heads = np.zeros(100); 
    pB_heads = np.zeros(100); 

    pA_heads[0] = np.random.rand() # initial guess
    pB_heads[0] = np.random.rand() # initial guess
    initialGuessA=pA_heads[0]
    initialGuessB=pB_heads[0]
    initialGuessesA.append(initialGuessA)
    initialGuessesB.append(initialGuessB)
    print('pA initial guess is: '+str(pA_heads[0]))
    print('pB initial guess is: '+str(pB_heads[0]))

    # E-M begins!
    epsilon = 0.001   # error threshold
    j = 0 # iteration counter
    improvement = float('inf')

    while (improvement > epsilon):

        expectation_A = np.zeros((num_exp,2), dtype=float) 
        expectation_B = np.zeros((num_exp,2), dtype=float)

        for i in np.arange(min(len(head_counts),len(tail_counts))):

            eH = head_counts[i]
            eT = tail_counts[i]

            # E step:
            lA = compute_likelihood(eH, num_coin_toss, pA_heads[j])
            lB = compute_likelihood(eH, num_coin_toss, pB_heads[j])

            weightA = lA / (lA + lB)
            weightB = lB / (lA + lB)

            expectation_A[i] = weightA*np.array([eH, eT])
            expectation_B[i] = weightB*np.array([eH, eT])


        # M step
        theta_A = np.sum(expectation_A, axis = 0)[0] / np.sum(expectation_A) 
        theta_B = np.sum(expectation_B, axis = 0)[0] / np.sum(expectation_B) 

        #print('At iteration %d, theta_A = %2f,  theta_B = %2f' % (j, theta_A, theta_B))

        pA_heads[j+1] = sum(expectation_A)[0] / sum(sum(expectation_A)); 
        pB_heads[j+1] = sum(expectation_B)[0] / sum(sum(expectation_B)); 

        improvement = max( abs(np.array([pA_heads[j+1],pB_heads[j+1]]) - np.array([pA_heads[j],pB_heads[j]]) ))
        j = j+1

    # END of E-M, print the outcome
    
    errorsA.append(theta_A-.8)
    errorsB.append(theta_B-.4)
    
    differencesFromTrueThetaA.append(initialGuessA-.8)
    differencesFromTrueThetaB.append(initialGuessB-.4)

    #print('E-M converges at iteration %d' %j)
    print('RESULT:')
    print('E-M: theta_A = %2f,  theta_B = %2f' % (theta_A, theta_B))
    print('Error is: theta_A =%2f, theta_B=%2f' % (theta_A-.8,theta_B-.4))
    print('Difference between guesses are: theta_A =%2f, theta_B=%2f' % (initialGuessA-.8,initialGuessB-.4))
    print('\n')
    
    #print('MLE with complete data: theta_A = %2f,  theta_B = %2f' % (MLE_A, MLE_B))
# Out:
# pA initial guess is: 0.44869126348799004
# pB initial guess is: 0.1772804121381174
# RESULT:
# E-M: theta_A = 0.358825,  theta_B = 0.244030
# Error is: theta_A =-0.441175, theta_B=-0.155970
# Difference between guesses are: theta_A =-0.351309, theta_B=-0.222720
#
#
# pA initial guess is: 0.016236626335775828
# pB initial guess is: 0.3286308014240851
# RESULT:
# E-M: theta_A = 0.478421,  theta_B = 0.562065
# Error is: theta_A =-0.321579, theta_B=0.162065
# Difference between guesses are: theta_A =-0.783763, theta_B=-0.071369
#
#
# pA initial guess is: 0.07036833799116526
# pB initial guess is: 0.0007744876090944874
# RESULT:
# E-M: theta_A = 0.760062,  theta_B = 0.759938
# Error is: theta_A =-0.039938, theta_B=0.359938
# Difference between guesses are: theta_A =-0.729632, theta_B=-0.399226
#
#
# pA initial guess is: 0.5575096174481601
# pB initial guess is: 0.015538728856034134
# RESULT:
# E-M: theta_A = 0.831791,  theta_B = 0.302150
# Error is: theta_A =0.031791, theta_B=-0.097850
# Difference between guesses are: theta_A =-0.242490, theta_B=-0.384461
#
#
# pA initial guess is: 0.13757141018123642
# pB initial guess is: 0.11745695567333214
# RESULT:
# E-M: theta_A = 1.000000,  theta_B = 0.425028
# Error is: theta_A =0.200000, theta_B=0.025028
# Difference between guesses are: theta_A =-0.662429, theta_B=-0.282543
#
#
# pA initial guess is: 0.39591231270815586
# pB initial guess is: 0.8267937654726584
# RESULT:
# E-M: theta_A = 0.610165,  theta_B = 0.629838
# Error is: theta_A =-0.189835, theta_B=0.229838
# Difference between guesses are: theta_A =-0.404088, theta_B=0.426794
#
#
# pA initial guess is: 0.0732285468453383
# pB initial guess is: 0.24105813977067436
# RESULT:
# E-M: theta_A = 0.059414,  theta_B = 0.427361
# Error is: theta_A =-0.740586, theta_B=0.027361
# Difference between guesses are: theta_A =-0.726771, theta_B=-0.158942
#
#
# pA initial guess is: 0.6443367580396353
# pB initial guess is: 0.1851394642077745
# RESULT:
# E-M: theta_A = 1.000000,  theta_B = 0.450047
# Error is: theta_A =0.200000, theta_B=0.050047
# Difference between guesses are: theta_A =-0.155663, theta_B=-0.214861
#
#
# pA initial guess is: 0.8311135997365751
# pB initial guess is: 0.979030367075652
# RESULT:
# E-M: theta_A = 0.384383,  theta_B = 0.722913
# Error is: theta_A =-0.415617, theta_B=0.322913
# Difference between guesses are: theta_A =0.031114, theta_B=0.579030
#
#
# pA initial guess is: 0.7019005188598169
# pB initial guess is: 0.27784296491199123
# RESULT:
# E-M: theta_A = 0.886609,  theta_B = 0.536034
# Error is: theta_A =0.086609, theta_B=0.136034
# Difference between guesses are: theta_A =-0.098099, theta_B=-0.122157
#
#
# pA initial guess is: 0.8918081509494501
# pB initial guess is: 0.71235494833939
# RESULT:
# E-M: theta_A = 0.760940,  theta_B = 0.759060
# Error is: theta_A =-0.039060, theta_B=0.359060
# Difference between guesses are: theta_A =0.091808, theta_B=0.312355
#
#
# pA initial guess is: 0.9172580155653929
# pB initial guess is: 0.7265525536629119
# RESULT:
# E-M: theta_A = 0.733413,  theta_B = 0.389020
# Error is: theta_A =-0.066587, theta_B=-0.010980
# Difference between guesses are: theta_A =0.117258, theta_B=0.326553
#
#
# pA initial guess is: 0.14871099110188302
# pB initial guess is: 0.013090039512222429
# RESULT:
# E-M: theta_A = 0.736667,  theta_B = 0.470118
# Error is: theta_A =-0.063333, theta_B=0.070118
# Difference between guesses are: theta_A =-0.651289, theta_B=-0.386910
#
#
# pA initial guess is: 0.4985949412702003
# pB initial guess is: 0.18131385632043395
# RESULT:
# E-M: theta_A = 0.901818,  theta_B = 0.557633
# Error is: theta_A =0.101818, theta_B=0.157633
# Difference between guesses are: theta_A =-0.301405, theta_B=-0.218686
#
#
# pA initial guess is: 0.0602746431711626
# pB initial guess is: 0.02427040598057051
# RESULT:
# E-M: theta_A = 0.400086,  theta_B = 0.399914
# Error is: theta_A =-0.399914, theta_B=-0.000086
# Difference between guesses are: theta_A =-0.739725, theta_B=-0.375730
#
#
# pA initial guess is: 0.7506406214647684
# pB initial guess is: 0.5678131002132725
# RESULT:
# E-M: theta_A = 0.825135,  theta_B = 0.101201
# Error is: theta_A =0.025135, theta_B=-0.298799
# Difference between guesses are: theta_A =-0.049359, theta_B=0.167813
#
#
# pA initial guess is: 0.5108343217341234
# pB initial guess is: 0.743080512267255
# RESULT:
# E-M: theta_A = 0.550286,  theta_B = 1.000000
# Error is: theta_A =-0.249714, theta_B=0.600000
# Difference between guesses are: theta_A =-0.289166, theta_B=0.343081
#
#
# pA initial guess is: 0.015513459503547544
# pB initial guess is: 0.1981628018721835
# RESULT:
# E-M: theta_A = 0.349275,  theta_B = 0.822833
# Error is: theta_A =-0.450725, theta_B=0.422833
# Difference between guesses are: theta_A =-0.784487, theta_B=-0.201837
#
#
# pA initial guess is: 0.3619696096459155
# pB initial guess is: 0.07375176821371598
# RESULT:
# E-M: theta_A = 0.894728,  theta_B = 0.349710
# Error is: theta_A =0.094728, theta_B=-0.050290
# Difference between guesses are: theta_A =-0.438030, theta_B=-0.326248
#
#
# pA initial guess is: 0.07315465201859961
# pB initial guess is: 0.8871415296783723
# RESULT:
# E-M: theta_A = 0.739267,  theta_B = 0.740733
# Error is: theta_A =-0.060733, theta_B=0.340733
# Difference between guesses are: theta_A =-0.726845, theta_B=0.487142
#
#
# pA initial guess is: 0.6388792342715568
# pB initial guess is: 0.8839021165518035
# RESULT:
# E-M: theta_A = 0.312107,  theta_B = 0.765041
# Error is: theta_A =-0.487893, theta_B=0.365041
# Difference between guesses are: theta_A =-0.161121, theta_B=0.483902
#
#
# pA initial guess is: 0.8872706417586652
# pB initial guess is: 0.8593032225876367
# RESULT:
# E-M: theta_A = 0.900723,  theta_B = 0.355887
# Error is: theta_A =0.100723, theta_B=-0.044113
# Difference between guesses are: theta_A =0.087271, theta_B=0.459303
#
#
# pA initial guess is: 0.9315127192869403
# pB initial guess is: 0.07867071062963427
# RESULT:
# E-M: theta_A = 0.639804,  theta_B = 0.520495
# Error is: theta_A =-0.160196, theta_B=0.120495
# Difference between guesses are: theta_A =0.131513, theta_B=-0.321329
#
#
# pA initial guess is: 0.5008275555508378
# pB initial guess is: 0.6949476850572679
# RESULT:
# E-M: theta_A = 0.534447,  theta_B = 0.697176
# Error is: theta_A =-0.265553, theta_B=0.297176
# Difference between guesses are: theta_A =-0.299172, theta_B=0.294948
#
#
# pA initial guess is: 0.023111607029520642
# pB initial guess is: 0.4770391710764238
# RESULT:
# E-M: theta_A = 0.444422,  theta_B = 0.795756
# Error is: theta_A =-0.355578, theta_B=0.395756
# Difference between guesses are: theta_A =-0.776888, theta_B=0.077039
#
#
# pA initial guess is: 0.22109264030128317
# pB initial guess is: 0.48496773890100564
# RESULT:
# E-M: theta_A = 0.320418,  theta_B = 0.838983
# Error is: theta_A =-0.479582, theta_B=0.438983
# Difference between guesses are: theta_A =-0.578907, theta_B=0.084968
#
#
# pA initial guess is: 0.6145639670021756
# pB initial guess is: 0.3032862532060857
# RESULT:
# E-M: theta_A = 0.778241,  theta_B = 0.518878
# Error is: theta_A =-0.021759, theta_B=0.118878
# Difference between guesses are: theta_A =-0.185436, theta_B=-0.096714
#
#
# pA initial guess is: 0.035659107769934306
# pB initial guess is: 0.4479764790297036
# RESULT:
# E-M: theta_A = 0.238472,  theta_B = 0.683388
# Error is: theta_A =-0.561528, theta_B=0.283388
# Difference between guesses are: theta_A =-0.764341, theta_B=0.047976
#
#
# pA initial guess is: 0.9345706427463427
# pB initial guess is: 0.96011525458982
# RESULT:
# E-M: theta_A = 0.370296,  theta_B = 0.630066
# Error is: theta_A =-0.429704, theta_B=0.230066
# Difference between guesses are: theta_A =0.134571, theta_B=0.560115
#
#
# pA initial guess is: 0.11460554651416388
# pB initial guess is: 0.7167354424856921
# RESULT:
# E-M: theta_A = 0.359527,  theta_B = 0.756663
# Error is: theta_A =-0.440473, theta_B=0.356663
# Difference between guesses are: theta_A =-0.685394, theta_B=0.316735
#
#
# pA initial guess is: 0.26560575652236085
# pB initial guess is: 0.13804318577485963
# RESULT:
# E-M: theta_A = 0.891847,  theta_B = 0.299012
# Error is: theta_A =0.091847, theta_B=-0.100988
# Difference between guesses are: theta_A =-0.534394, theta_B=-0.261957
#
#
# pA initial guess is: 0.44074791750516473
# pB initial guess is: 0.11872719547689281
# RESULT:
# E-M: theta_A = 0.611015,  theta_B = 0.266649
# Error is: theta_A =-0.188985, theta_B=-0.133351
# Difference between guesses are: theta_A =-0.359252, theta_B=-0.281273
#
#
# pA initial guess is: 0.4779833434352432
# pB initial guess is: 0.004971134636904351
# RESULT:
# E-M: theta_A = 0.803896,  theta_B = 0.415690
# Error is: theta_A =0.003896, theta_B=0.015690
# Difference between guesses are: theta_A =-0.322017, theta_B=-0.395029
#
#
# pA initial guess is: 0.22331785772354396
# pB initial guess is: 0.3342560273616907
# RESULT:
# E-M: theta_A = 0.381900,  theta_B = 0.795797
# Error is: theta_A =-0.418100, theta_B=0.395797
# Difference between guesses are: theta_A =-0.576682, theta_B=-0.065744
#
#
# pA initial guess is: 0.6140932587794574
# pB initial guess is: 0.4590164466881501
# RESULT:
# E-M: theta_A = 0.897588,  theta_B = 0.332990
# Error is: theta_A =0.097588, theta_B=-0.067010
# Difference between guesses are: theta_A =-0.185907, theta_B=0.059016
#
#
# pA initial guess is: 0.04469919682610424
# pB initial guess is: 0.5235641197348548
# RESULT:
# E-M: theta_A = 0.100814,  theta_B = 0.800080
# Error is: theta_A =-0.699186, theta_B=0.400080
# Difference between guesses are: theta_A =-0.755301, theta_B=0.123564
#
#
# pA initial guess is: 0.6557069120816671
# pB initial guess is: 0.9127432852302728
# RESULT:
# E-M: theta_A = 0.372354,  theta_B = 0.787137
# Error is: theta_A =-0.427646, theta_B=0.387137
# Difference between guesses are: theta_A =-0.144293, theta_B=0.512743
#
#
# pA initial guess is: 0.5422594685241207
# pB initial guess is: 0.21377195220189793
# RESULT:
# E-M: theta_A = 0.949355,  theta_B = 0.469111
# Error is: theta_A =0.149355, theta_B=0.069111
# Difference between guesses are: theta_A =-0.257741, theta_B=-0.186228
#
#
# pA initial guess is: 0.7667502969213459
# pB initial guess is: 0.5819163128618559
# RESULT:
# E-M: theta_A = 0.716870,  theta_B = 0.683135
# Error is: theta_A =-0.083130, theta_B=0.283135
# Difference between guesses are: theta_A =-0.033250, theta_B=0.181916
#
#
# pA initial guess is: 0.8623801436771611
# pB initial guess is: 0.643175121555965
# RESULT:
# E-M: theta_A = 0.821789,  theta_B = 0.818211
# Error is: theta_A =0.021789, theta_B=0.418211
# Difference between guesses are: theta_A =0.062380, theta_B=0.243175
#
#
# pA initial guess is: 0.3877204404756476
# pB initial guess is: 0.6847682895081529
# RESULT:
# E-M: theta_A = 0.536846,  theta_B = 0.747089
# Error is: theta_A =-0.263154, theta_B=0.347089
# Difference between guesses are: theta_A =-0.412280, theta_B=0.284768
#
#
# pA initial guess is: 0.32633309263214194
# pB initial guess is: 0.6399338943728206
# RESULT:
# E-M: theta_A = 0.386763,  theta_B = 0.864886
# Error is: theta_A =-0.413237, theta_B=0.464886
# Difference between guesses are: theta_A =-0.473667, theta_B=0.239934
#
#
# pA initial guess is: 0.3946848556027537
# pB initial guess is: 0.5101806251860402
# RESULT:
# E-M: theta_A = 0.537684,  theta_B = 0.695313
# Error is: theta_A =-0.262316, theta_B=0.295313
# Difference between guesses are: theta_A =-0.405315, theta_B=0.110181
#
#
# pA initial guess is: 0.6203791126549365
# pB initial guess is: 0.12659110263318685
# RESULT:
# E-M: theta_A = 0.788355,  theta_B = 0.731493
# Error is: theta_A =-0.011645, theta_B=0.331493
# Difference between guesses are: theta_A =-0.179621, theta_B=-0.273409
#
#
# pA initial guess is: 0.1997914119102362
# pB initial guess is: 0.24632907059567988
# RESULT:
# E-M: theta_A = 0.407427,  theta_B = 0.901358
# Error is: theta_A =-0.392573, theta_B=0.501358
# Difference between guesses are: theta_A =-0.600209, theta_B=-0.153671
#
#
# pA initial guess is: 0.1756239195728394
# pB initial guess is: 0.2978807950678901
# RESULT:
# E-M: theta_A = 0.350027,  theta_B = 1.000000
# Error is: theta_A =-0.449973, theta_B=0.600000
# Difference between guesses are: theta_A =-0.624376, theta_B=-0.102119
#
#
# pA initial guess is: 0.48917181728818615
# pB initial guess is: 0.8220751216155435
# RESULT:
# E-M: theta_A = 0.414914,  theta_B = 0.776071
# Error is: theta_A =-0.385086, theta_B=0.376071
# Difference between guesses are: theta_A =-0.310828, theta_B=0.422075
#
#
# pA initial guess is: 0.3163363999614518
# pB initial guess is: 0.49229247829233946
# RESULT:
# E-M: theta_A = 0.576592,  theta_B = 0.933482
# Error is: theta_A =-0.223408, theta_B=0.533482
# Difference between guesses are: theta_A =-0.483664, theta_B=0.092292
#
#
# pA initial guess is: 0.8670045830264428
# pB initial guess is: 0.6330986930634147
# RESULT:
# E-M: theta_A = 0.765499,  theta_B = 0.253775
# Error is: theta_A =-0.034501, theta_B=-0.146225
# Difference between guesses are: theta_A =0.067005, theta_B=0.233099
#
#
# pA initial guess is: 0.7753294908281374
# pB initial guess is: 0.07606909848340182
# RESULT:
# E-M: theta_A = 0.683482,  theta_B = 0.676518
# Error is: theta_A =-0.116518, theta_B=0.276518
# Difference between guesses are: theta_A =-0.024671, theta_B=-0.323931
#
#
# pA initial guess is: 0.07318290836743047
# pB initial guess is: 0.5197134982934383
# RESULT:
# E-M: theta_A = 0.480524,  theta_B = 0.830437
# Error is: theta_A =-0.319476, theta_B=0.430437
# Difference between guesses are: theta_A =-0.726817, theta_B=0.119713
#
#
# pA initial guess is: 0.8753843622053683
# pB initial guess is: 0.7611670028261359
# RESULT:
# E-M: theta_A = 0.675680,  theta_B = 0.417182
# Error is: theta_A =-0.124320, theta_B=0.017182
# Difference between guesses are: theta_A =0.075384, theta_B=0.361167
#
#
# pA initial guess is: 0.2141479120294315
# pB initial guess is: 0.4675131798224422
# RESULT:
# E-M: theta_A = 0.238056,  theta_B = 0.595724
# Error is: theta_A =-0.561944, theta_B=0.195724
# Difference between guesses are: theta_A =-0.585852, theta_B=0.067513
#
#
# pA initial guess is: 0.3949076838918335
# pB initial guess is: 0.6286730467711751
# RESULT:
# E-M: theta_A = 0.259929,  theta_B = 0.490436
# Error is: theta_A =-0.540071, theta_B=0.090436
# Difference between guesses are: theta_A =-0.405092, theta_B=0.228673
#
#
# pA initial guess is: 0.9278770045457786
# pB initial guess is: 0.7346193386941181
# RESULT:
# E-M: theta_A = 0.676369,  theta_B = 0.416677
# Error is: theta_A =-0.123631, theta_B=0.016677
# Difference between guesses are: theta_A =0.127877, theta_B=0.334619
#
#
# pA initial guess is: 0.4799908498316595
# pB initial guess is: 0.7755417518624887
# RESULT:
# E-M: theta_A = 0.870896,  theta_B = 0.889104
# Error is: theta_A =0.070896, theta_B=0.489104
# Difference between guesses are: theta_A =-0.320009, theta_B=0.375542
#
#
# pA initial guess is: 0.3207187594028382
# pB initial guess is: 0.4391361445233576
# RESULT:
# E-M: theta_A = 0.366678,  theta_B = 0.620419
# Error is: theta_A =-0.433322, theta_B=0.220419
# Difference between guesses are: theta_A =-0.479281, theta_B=0.039136
#
#
# pA initial guess is: 0.23036395253072328
# pB initial guess is: 0.20931970946246992
# RESULT:
# E-M: theta_A = 0.649996,  theta_B = 0.000000
# Error is: theta_A =-0.150004, theta_B=-0.400000
# Difference between guesses are: theta_A =-0.569636, theta_B=-0.190680
#
#
# pA initial guess is: 0.2761198244648242
# pB initial guess is: 0.7169191250782482
# RESULT:
# E-M: theta_A = 0.609421,  theta_B = 0.782905
# Error is: theta_A =-0.190579, theta_B=0.382905
# Difference between guesses are: theta_A =-0.523880, theta_B=0.316919
#
#
# pA initial guess is: 0.8651184731533057
# pB initial guess is: 0.033883652833430644
# RESULT:
# E-M: theta_A = 0.726079,  theta_B = 0.713921
# Error is: theta_A =-0.073921, theta_B=0.313921
# Difference between guesses are: theta_A =0.065118, theta_B=-0.366116
#
#
# pA initial guess is: 0.11406071474301138
# pB initial guess is: 0.913498052108416
# RESULT:
# E-M: theta_A = 0.206901,  theta_B = 0.643066
# Error is: theta_A =-0.593099, theta_B=0.243066
# Difference between guesses are: theta_A =-0.685939, theta_B=0.513498
#
#
# pA initial guess is: 0.6770288459867337
# pB initial guess is: 0.2143586644540354
# RESULT:
# E-M: theta_A = 0.866555,  theta_B = 0.354810
# Error is: theta_A =0.066555, theta_B=-0.045190
# Difference between guesses are: theta_A =-0.122971, theta_B=-0.185641
#
#
# pA initial guess is: 0.6226811134688433
# pB initial guess is: 0.13165166045075316
# RESULT:
# E-M: theta_A = 0.864535,  theta_B = 0.548166
# Error is: theta_A =0.064535, theta_B=0.148166
# Difference between guesses are: theta_A =-0.177319, theta_B=-0.268348
#
#
# pA initial guess is: 0.54284630247425
# pB initial guess is: 0.5245768920021388
# RESULT:
# E-M: theta_A = 0.408723,  theta_B = 0.391278
# Error is: theta_A =-0.391277, theta_B=-0.008722
# Difference between guesses are: theta_A =-0.257154, theta_B=0.124577
#
#
# pA initial guess is: 0.4094275222010523
# pB initial guess is: 0.6275061581244051
# RESULT:
# E-M: theta_A = 0.399425,  theta_B = 0.400575
# Error is: theta_A =-0.400575, theta_B=0.000575
# Difference between guesses are: theta_A =-0.390572, theta_B=0.227506
#
#
# pA initial guess is: 0.3448765811790976
# pB initial guess is: 0.37597127006278785
# RESULT:
# E-M: theta_A = 0.200215,  theta_B = 0.875005
# Error is: theta_A =-0.599785, theta_B=0.475005
# Difference between guesses are: theta_A =-0.455123, theta_B=-0.024029
#
#
# pA initial guess is: 0.07572959430986625
# pB initial guess is: 0.2725834694967355
# RESULT:
# E-M: theta_A = 0.602320,  theta_B = 0.918755
# Error is: theta_A =-0.197680, theta_B=0.518755
# Difference between guesses are: theta_A =-0.724270, theta_B=-0.127417
#
#
# pA initial guess is: 0.7918541917510075
# pB initial guess is: 0.12976210735060867
# RESULT:
# E-M: theta_A = 0.949410,  theta_B = 0.469153
# Error is: theta_A =0.149410, theta_B=0.069153
# Difference between guesses are: theta_A =-0.008146, theta_B=-0.270238
#
#
# pA initial guess is: 0.6010526312622954
# pB initial guess is: 0.41799184753835394
# RESULT:
# E-M: theta_A = 0.739257,  theta_B = 0.351010
# Error is: theta_A =-0.060743, theta_B=-0.048990
# Difference between guesses are: theta_A =-0.198947, theta_B=0.017992
#
#
# pA initial guess is: 0.7316104470722656
# pB initial guess is: 0.08838546812127535
# RESULT:
# E-M: theta_A = 0.798782,  theta_B = 0.234793
# Error is: theta_A =-0.001218, theta_B=-0.165207
# Difference between guesses are: theta_A =-0.068390, theta_B=-0.311615
#
#
# pA initial guess is: 0.7264580590028119
# pB initial guess is: 0.2327786341941286
# RESULT:
# E-M: theta_A = 0.734517,  theta_B = 0.209068
# Error is: theta_A =-0.065483, theta_B=-0.190932
# Difference between guesses are: theta_A =-0.073542, theta_B=-0.167221
#
#
# pA initial guess is: 0.08674317332306603
# pB initial guess is: 0.562602359301168
# RESULT:
# E-M: theta_A = 0.250468,  theta_B = 0.866652
# Error is: theta_A =-0.549532, theta_B=0.466652
# Difference between guesses are: theta_A =-0.713257, theta_B=0.162602
#
#
# pA initial guess is: 0.8460049097816772
# pB initial guess is: 0.28415375813600563
# RESULT:
# E-M: theta_A = 0.468399,  theta_B = 0.327104
# Error is: theta_A =-0.331601, theta_B=-0.072896
# Difference between guesses are: theta_A =0.046005, theta_B=-0.115846
#
#
# pA initial guess is: 0.6217783554385037
# pB initial guess is: 0.4674599202019548
# RESULT:
# E-M: theta_A = 0.627818,  theta_B = 0.493946
# Error is: theta_A =-0.172182, theta_B=0.093946
# Difference between guesses are: theta_A =-0.178222, theta_B=0.067460
#
#
# pA initial guess is: 0.12421936263351552
# pB initial guess is: 0.5236653414291007
# RESULT:
# E-M: theta_A = 0.686554,  theta_B = 0.896992
# Error is: theta_A =-0.113446, theta_B=0.496992
# Difference between guesses are: theta_A =-0.675781, theta_B=0.123665
#
#
# pA initial guess is: 0.3370579223500165
# pB initial guess is: 0.19854257941486297
# RESULT:
# E-M: theta_A = 0.784268,  theta_B = 0.490929
# Error is: theta_A =-0.015732, theta_B=0.090929
# Difference between guesses are: theta_A =-0.462942, theta_B=-0.201457
#
#
# pA initial guess is: 0.4875541781320605
# pB initial guess is: 0.9270000041751082
# RESULT:
# E-M: theta_A = 0.537744,  theta_B = 0.542256
# Error is: theta_A =-0.262256, theta_B=0.142256
# Difference between guesses are: theta_A =-0.312446, theta_B=0.527000
#
#
# pA initial guess is: 0.5245989588698299
# pB initial guess is: 0.6900015289913025
# RESULT:
# E-M: theta_A = 0.759718,  theta_B = 0.760282
# Error is: theta_A =-0.040282, theta_B=0.360282
# Difference between guesses are: theta_A =-0.275401, theta_B=0.290002
#
#
# pA initial guess is: 0.8663965981312652
# pB initial guess is: 0.5890252067830152
# RESULT:
# E-M: theta_A = 0.737895,  theta_B = 0.470761
# Error is: theta_A =-0.062105, theta_B=0.070761
# Difference between guesses are: theta_A =0.066397, theta_B=0.189025
#
#
# pA initial guess is: 0.7859272156489643
# pB initial guess is: 0.820192183829869
# RESULT:
# E-M: theta_A = 0.380013,  theta_B = 0.760845
# Error is: theta_A =-0.419987, theta_B=0.360845
# Difference between guesses are: theta_A =-0.014073, theta_B=0.420192
#
#
# pA initial guess is: 0.8271419672250571
# pB initial guess is: 0.3227118776248493
# RESULT:
# E-M: theta_A = 0.777629,  theta_B = 0.366645
# Error is: theta_A =-0.022371, theta_B=-0.033355
# Difference between guesses are: theta_A =0.027142, theta_B=-0.077288
#
#
# pA initial guess is: 0.25023236503228463
# pB initial guess is: 0.1840918937206475
# RESULT:
# E-M: theta_A = 0.716493,  theta_B = 0.683512
# Error is: theta_A =-0.083507, theta_B=0.283512
# Difference between guesses are: theta_A =-0.549768, theta_B=-0.215908
#
#
# pA initial guess is: 0.14318107329628638
# pB initial guess is: 0.49365743662585737
# RESULT:
# E-M: theta_A = 0.450047,  theta_B = 1.000000
# Error is: theta_A =-0.349953, theta_B=0.600000
# Difference between guesses are: theta_A =-0.656819, theta_B=0.093657
#
#
# pA initial guess is: 0.8585927918057945
# pB initial guess is: 0.4887616949193794
# RESULT:
# E-M: theta_A = 0.759873,  theta_B = 0.308596
# Error is: theta_A =-0.040127, theta_B=-0.091404
# Difference between guesses are: theta_A =0.058593, theta_B=0.088762
#
#
# pA initial guess is: 0.7122019739686256
# pB initial guess is: 0.5298792756089153
# RESULT:
# E-M: theta_A = 0.740309,  theta_B = 0.739691
# Error is: theta_A =-0.059691, theta_B=0.339691
# Difference between guesses are: theta_A =-0.087798, theta_B=0.129879
#
#
# pA initial guess is: 0.16970666324411843
# pB initial guess is: 0.4461538167322495
# RESULT:
# E-M: theta_A = 0.354753,  theta_B = 0.866537
# Error is: theta_A =-0.445247, theta_B=0.466537
# Difference between guesses are: theta_A =-0.630293, theta_B=0.046154
#
#
# pA initial guess is: 0.8470777949827959
# pB initial guess is: 0.8316318069071776
# RESULT:
# E-M: theta_A = 0.562386,  theta_B = 0.557614
# Error is: theta_A =-0.237614, theta_B=0.157614
# Difference between guesses are: theta_A =0.047078, theta_B=0.431632
#
#
# pA initial guess is: 0.14002078174844124
# pB initial guess is: 0.6365551625117525
# RESULT:
# E-M: theta_A = 0.552665,  theta_B = 0.724628
# Error is: theta_A =-0.247335, theta_B=0.324628
# Difference between guesses are: theta_A =-0.659979, theta_B=0.236555
#
#
# pA initial guess is: 0.30283537413924266
# pB initial guess is: 0.3105833000499644
# RESULT:
# E-M: theta_A = 0.614937,  theta_B = 0.625062
# Error is: theta_A =-0.185063, theta_B=0.225062
# Difference between guesses are: theta_A =-0.497165, theta_B=-0.089417
#
#
# pA initial guess is: 0.6446912955602698
# pB initial guess is: 0.5579900636257658
# RESULT:
# E-M: theta_A = 0.601112,  theta_B = 0.441876
# Error is: theta_A =-0.198888, theta_B=0.041876
# Difference between guesses are: theta_A =-0.155309, theta_B=0.157990
#
#
# pA initial guess is: 0.8800733431668369
# pB initial guess is: 0.9864078852930966
# RESULT:
# E-M: theta_A = 0.531864,  theta_B = 0.548137
# Error is: theta_A =-0.268136, theta_B=0.148137
# Difference between guesses are: theta_A =0.080073, theta_B=0.586408
#
#
# pA initial guess is: 0.905844566875634
# pB initial guess is: 0.7097290233891705
# RESULT:
# E-M: theta_A = 0.840900,  theta_B = 0.839100
# Error is: theta_A =0.040900, theta_B=0.439100
# Difference between guesses are: theta_A =0.105845, theta_B=0.309729
#
#
# pA initial guess is: 0.9802159857030421
# pB initial guess is: 0.413335401189177
# RESULT:
# E-M: theta_A = 0.948472,  theta_B = 0.400231
# Error is: theta_A =0.148472, theta_B=0.000231
# Difference between guesses are: theta_A =0.180216, theta_B=0.013335
#
#
# pA initial guess is: 0.25557163467835164
# pB initial guess is: 0.5410556813107655
# RESULT:
# E-M: theta_A = 0.201935,  theta_B = 0.689363
# Error is: theta_A =-0.598065, theta_B=0.289363
# Difference between guesses are: theta_A =-0.544428, theta_B=0.141056
#
#
# pA initial guess is: 0.6075143562386898
# pB initial guess is: 0.6824125230503058
# RESULT:
# E-M: theta_A = 0.647478,  theta_B = 0.750795
# Error is: theta_A =-0.152522, theta_B=0.350795
# Difference between guesses are: theta_A =-0.192486, theta_B=0.282413
#
#
# pA initial guess is: 0.47600744089492153
# pB initial guess is: 0.7700617138753807
# RESULT:
# E-M: theta_A = 0.203587,  theta_B = 0.850256
# Error is: theta_A =-0.596413, theta_B=0.450256
# Difference between guesses are: theta_A =-0.323993, theta_B=0.370062
#
#
# pA initial guess is: 0.6695455628098997
# pB initial guess is: 0.5345494008975993
# RESULT:
# E-M: theta_A = 0.868629,  theta_B = 0.257917
# Error is: theta_A =0.068629, theta_B=-0.142083
# Difference between guesses are: theta_A =-0.130454, theta_B=0.134549
#
#
# pA initial guess is: 0.5437252762103232
# pB initial guess is: 0.03716838998053984
# RESULT:
# E-M: theta_A = 0.320428,  theta_B = 0.319572
# Error is: theta_A =-0.479572, theta_B=-0.080428
# Difference between guesses are: theta_A =-0.256275, theta_B=-0.362832
#
#
# pA initial guess is: 0.016635747464497808
# pB initial guess is: 0.2134939344940544
# RESULT:
# E-M: theta_A = 0.232897,  theta_B = 0.847589
# Error is: theta_A =-0.567103, theta_B=0.447589
# Difference between guesses are: theta_A =-0.783364, theta_B=-0.186506
#
#
# pA initial guess is: 0.38390897015990555
# pB initial guess is: 0.678373934747284
# RESULT:
# E-M: theta_A = 0.388563,  theta_B = 0.597086
# Error is: theta_A =-0.411437, theta_B=0.197086
# Difference between guesses are: theta_A =-0.416091, theta_B=0.278374

# %%
import matplotlib.pyplot as plt

print("number of coin tosses = " + str(num_coin_toss))
plt.plot(differencesFromTrueThetaA,np.abs(errorsA),'o')
plt.xlabel('Difference between True Theta and Guess')
plt.ylabel('Error between EM and True')
plt.title('Theta_A')
plt.show
# Out:
# number of coin tosses = 10
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("number of coin tosses = " + str(num_coin_toss))
plt.plot(differencesFromTrueThetaB,np.abs(errorsB),'o')
plt.xlabel('Difference between True Theta and Guess')
plt.ylabel('Error between EM and True')
plt.title('Theta_B')
plt.show
# Out:
# number of coin tosses = 10
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("number of coin tosses = " + str(num_coin_toss))
plt.plot(initialGuessesB,np.abs(errorsB),'o')
plt.xlabel('initialGuesses')
plt.ylabel('Error between EM and True')
plt.title('Theta_B')
plt.show
# Out:
# number of coin tosses = 10
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print("number of coin tosses = " + str(num_coin_toss))
plt.plot(initialGuessesA,np.abs(errorsA),'o')
plt.xlabel('InitialGuesses')
plt.ylabel('Error between EM and True')
plt.title('Theta_A')
plt.show
# Out:
# number of coin tosses = 10
# <function matplotlib.pyplot.show(*args, **kw)>
